# %% [markdown]
# <a href="https://colab.research.google.com/github/swarup7350/python_code/blob/master/Updated%20Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-930e4ce0-e139-4925-a1a4-a525654e0225" name="files[]" multiple disabled />
#      <output id="result-930e4ce0-e139-4925-a1a4-a525654e0225">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import pandas as pd
swarupdata= pd.read_csv('bugs-2019-11-29 (1).csv', sep=',', encoding='latin-1')

# %%
bugsdata
# Out:
#       Bug ID  ...              Changed
# 0      33853  ...  2019-11-28 20:00:10
# 1      33818  ...  2019-11-28 19:59:38
# 2      33876  ...  2019-11-28 19:57:58
# 3      33161  ...  2019-11-28 18:34:50
# 4      33885  ...  2019-11-28 18:31:50
# 5      33784  ...  2019-11-28 18:25:38
# 6      33622  ...  2019-11-28 18:24:43
# 7      33820  ...  2019-11-28 18:22:40
# 8      33738  ...  2019-11-28 18:21:28
# 9      33874  ...  2019-11-28 18:20:26
# 10     33864  ...  2019-11-28 17:16:53
# 11     33765  ...  2019-11-28 16:57:25
# 12     33754  ...  2019-11-28 16:29:12
# 13     33850  ...  2019-11-28 16:20:18
# 14     33772  ...  2019-11-28 15:54:01
# 15     33236  ...  2019-11-28 15:51:09
# 16     33685  ...  2019-11-28 15:48:57
# 17     33684  ...  2019-11-28 15:48:30
# 18     33405  ...  2019-11-28 15:41:54
# 19     33831  ...  2019-11-28 15:17:18
# 20     33832  ...  2019-11-28 15:05:54
# 21     33777  ...  2019-11-28 15:03:01
# 22     33773  ...  2019-11-28 15:02:02
# ...

# %%
swarupdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2894 entries, 0 to 2893
# Data columns (total 13 columns):
# Bug ID                                                    2894 non-null int64
# Product                                                   2894 non-null object
# Component                                                 2894 non-null object
# Assignee                                                  2894 non-null object
# Status                                                    2894 non-null object
# Resolution                                                2894 non-null object
# Summary                                                   2894 non-null object
# Start Date                                                2506 non-null object
# Deadline                                                  2510 non-null object
# Orig. Est.                                                2894 non-null float64
# ...

# %%
swarupdata.head(15)
# Out:
#     Bug ID  ...              Changed
# 0    33784  ...  2019-11-28 18:25:38
# 1    33765  ...  2019-11-28 16:57:25
# 2    33754  ...  2019-11-28 16:29:12
# 3    33850  ...  2019-11-28 16:20:18
# 4    33236  ...  2019-11-28 15:51:09
# 5    33685  ...  2019-11-28 15:48:57
# 6    33684  ...  2019-11-28 15:48:30
# 7    33405  ...  2019-11-28 15:41:54
# 8    33831  ...  2019-11-28 15:17:18
# 9    33832  ...  2019-11-28 15:05:54
# 10   33777  ...  2019-11-28 15:03:01
# 11   33773  ...  2019-11-28 15:02:02
# 12   33387  ...  2019-11-28 14:59:55
# 13   33774  ...  2019-11-28 14:59:11
# 14   33771  ...  2019-11-28 14:53:50
#
# [15 rows x 13 columns]

# %%
swarupdata.tail(15)
# Out:
#       Bug ID  ...              Changed
# 2879   23837  ...  2019-01-29 11:39:35
# 2880   23717  ...  2019-01-29 11:39:19
# 2881   23041  ...  2019-01-29 11:38:58
# 2882   24407  ...  2019-01-29 11:37:57
# 2883   21129  ...  2019-01-29 11:36:20
# 2884   22316  ...  2019-01-29 11:35:56
# 2885   22325  ...  2019-01-29 11:35:40
# 2886   21117  ...  2019-01-29 11:34:26
# 2887   22323  ...  2019-01-29 11:33:59
# 2888   21127  ...  2019-01-29 11:32:28
# 2889   24499  ...  2019-01-23 15:49:20
# 2890   21134  ...  2019-01-14 14:29:37
# 2891   21138  ...  2019-01-14 14:29:23
# 2892   21135  ...  2018-12-26 14:25:48
# 2893   15685  ...  2018-11-01 16:24:27
#
# [15 rows x 13 columns]

# %%
swarupdata.columns
# Out:
# Index([u'Bug ID', u'Product', u'Component', u'Assignee', u'Status',
#        u'Resolution', u'Summary', u'Start Date', u'Deadline', u'Orig. Est.',
#        u'Severity', u'Patch Release Version (Defect Closure-For Developers )',
#        u'Changed'],
#       dtype='object')

# %%
swarupdata.count()
# Out:
# Bug ID                                                    2894
# Product                                                   2894
# Component                                                 2894
# Assignee                                                  2894
# Status                                                    2894
# Resolution                                                2894
# Summary                                                   2894
# Start Date                                                2506
# Deadline                                                  2510
# Orig. Est.                                                2894
# Severity                                                  2894
# Patch Release Version (Defect Closure-For Developers )    2894
# Changed                                                   2894
# dtype: int64

# %%
swarupdata.sort_values(by, axis)
# Out:
#       Bug ID  ...              Changed
# 0      33784  ...  2019-11-28 18:25:38
# 1      33765  ...  2019-11-28 16:57:25
# 2      33754  ...  2019-11-28 16:29:12
# 3      33850  ...  2019-11-28 16:20:18
# 4      33236  ...  2019-11-28 15:51:09
# 5      33685  ...  2019-11-28 15:48:57
# 6      33684  ...  2019-11-28 15:48:30
# 7      33405  ...  2019-11-28 15:41:54
# 8      33831  ...  2019-11-28 15:17:18
# 9      33832  ...  2019-11-28 15:05:54
# 10     33777  ...  2019-11-28 15:03:01
# 11     33773  ...  2019-11-28 15:02:02
# 12     33387  ...  2019-11-28 14:59:55
# 13     33774  ...  2019-11-28 14:59:11
# 14     33771  ...  2019-11-28 14:53:50
# 15     33768  ...  2019-11-28 14:51:48
# 16     33846  ...  2019-11-28 14:49:16
# 17     33869  ...  2019-11-28 14:42:03
# 18     33286  ...  2019-11-27 14:28:01
# 19     33791  ...  2019-11-26 18:27:41
# 20     33653  ...  2019-11-26 18:17:32
# 21     33463  ...  2019-11-26 17:00:24
# 22     33489  ...  2019-11-26 12:20:19
# ...

# %%
profilehm = pandas_profiling.ProfileReport(swarupdata)
profilehm.to_file(outputfile="befprocess.html")
##befprof = swarupdata.profileReport(title='Pandas Profiling before Data Preprocessing')
##profilehm.profileReport(title='Pandas Profiling before Data Preprocessing', style={'full_width':True})

# %%
from google.colab import files
files.download("befprocess.html")

# %%
pandas_profiling.ProfileReport(swarupdata)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
