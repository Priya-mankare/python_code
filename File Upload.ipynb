# %% [markdown]
# <a href="https://colab.research.google.com/github/swarup7350/python_code/blob/master/File%20Upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=78
b=78
c=42
p=c+a-b
print(p)
# Out:
# 42

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d0ea10e6-beed-4dfa-8074-e970f09a3bf2" name="files[]" multiple disabled />
#      <output id="result-d0ea10e6-beed-4dfa-8074-e970f09a3bf2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bugs-2019-11-29.csv to bugs-2019-11-29.csv

# %%
import pandas as pd
hmisdata= pd.read_csv('bugs-2019-11-29.csv', sep=',', encoding='latin-1')

# %%
hmisdata
# Out:
#       Bug ID  ...              Changed
# 0      33853  ...  2019-11-28 20:00:10
# 1      33818  ...  2019-11-28 19:59:38
# 2      33876  ...  2019-11-28 19:57:58
# 3      33161  ...  2019-11-28 18:34:50
# 4      33885  ...  2019-11-28 18:31:50
# 5      33784  ...  2019-11-28 18:25:38
# 6      33622  ...  2019-11-28 18:24:43
# 7      33820  ...  2019-11-28 18:22:40
# 8      33738  ...  2019-11-28 18:21:28
# 9      33874  ...  2019-11-28 18:20:26
# 10     33864  ...  2019-11-28 17:16:53
# 11     33765  ...  2019-11-28 16:57:25
# 12     33754  ...  2019-11-28 16:29:12
# 13     33850  ...  2019-11-28 16:20:18
# 14     33772  ...  2019-11-28 15:54:01
# 15     33236  ...  2019-11-28 15:51:09
# 16     33685  ...  2019-11-28 15:48:57
# 17     33684  ...  2019-11-28 15:48:30
# 18     33405  ...  2019-11-28 15:41:54
# 19     33831  ...  2019-11-28 15:17:18
# 20     33832  ...  2019-11-28 15:05:54
# 21     33777  ...  2019-11-28 15:03:01
# 22     33773  ...  2019-11-28 15:02:02
# ...

# %%
hmisdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3615 entries, 0 to 3614
# Data columns (total 13 columns):
# Bug ID                                                    3615 non-null int64
# Product                                                   3615 non-null object
# Component                                                 3615 non-null object
# Assignee                                                  3615 non-null object
# Status                                                    3615 non-null object
# Resolution                                                3615 non-null object
# Summary                                                   3615 non-null object
# Start Date                                                3020 non-null object
# Deadline                                                  3053 non-null object
# Orig. Est.                                                3615 non-null float64
# ...

# %%
hmisdata.head(5)
# Out:
#    Bug ID  ...              Changed
# 0   33853  ...  2019-11-28 20:00:10
# 1   33818  ...  2019-11-28 19:59:38
# 2   33876  ...  2019-11-28 19:57:58
# 3   33161  ...  2019-11-28 18:34:50
# 4   33885  ...  2019-11-28 18:31:50
#
# [5 rows x 13 columns]

# %%
hmisdata.tail(5)
# Out:
#       Bug ID  ...              Changed
# 3610   21455  ...  2018-12-13 20:45:48
# 3611   21371  ...  2018-12-13 17:07:42
# 3612   21229  ...  2018-12-12 19:58:09
# 3613   18605  ...  2018-12-05 15:06:17
# 3614   15685  ...  2018-11-01 16:24:27
#
# [5 rows x 13 columns]

# %%
hmisdata.columns
# Out:
# Index([u'Bug ID', u'Product', u'Component', u'Assignee', u'Status',
#        u'Resolution', u'Summary', u'Start Date', u'Deadline', u'Orig. Est.',
#        u'Severity', u'Patch Release Version (Defect Closure-For Developers )',
#        u'Changed'],
#       dtype='object')

# %%
hmisdata.count()
# Out:
# Bug ID                                                    3615
# Product                                                   3615
# Component                                                 3615
# Assignee                                                  3615
# Status                                                    3615
# Resolution                                                3615
# Summary                                                   3615
# Start Date                                                3020
# Deadline                                                  3053
# Orig. Est.                                                3615
# Severity                                                  3615
# Patch Release Version (Defect Closure-For Developers )    3615
# Changed                                                   3615
# dtype: int64
